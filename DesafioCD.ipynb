# %% [markdown]
# # Exploração dos Dados
#
# ## Justificativa da escolha das estatísticas e gráficos:
#
# > Gráfico de Barra:
# >> Este tipo de gráfico foi escolhido pois apresenta de forma clara a diferença entre a quantidade de amostras para cada classe em atributos categóricos.
#
# > Histograma:
# >> Este tipo de gráfico foi escolhido pois apresenta de forma clara a quantidade de amostras para N intervalos de um atributo contínuo.
#
# > Estatísticas Descritivas:
# >> Foram usadas medidas de tendência central e medidas de disperção. A média foi escolhida pois representa a concentração dos dados, mas também foram usados os valores de mediana (valor da amostra central dos dados ordenados) e moda (valor que mais se repete), pois assim temos um entendimento mais fiel dos dados, diminuindo a influência dos outliers. Também foram usados os percentil 25% e 75%, para complementar o entendimento de como os valores de um atributo estão distribuidos. Os valores mínimos e máximo foram utilizados para conhecer a amplitude dos valores do atributo. A variância e desvio padrão também foram calculadas para entender como está a dispersão dos valores.
#
# > Boxplot:
# >> Basicamente uma representação visual das estatisticas apresentadas anteriormente, esse tipo de gráfico foi utilizado pois ele ajuda a avaliar a distribuição dos valores do atributo, também apresenta potenciais outliers dos dados.

# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Carregando a Base

# %%
df = pd.read_csv('wage_train.csv')
df = df.drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df_maior_que_50K = df.loc[df['yearly_wage'] == ' >50K']
df_maior_que_50K
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 6       52   Self-emp-not-inc  209642        HS-grad              9
# 7       31            Private   45781        Masters             14
# 8       42            Private  159449      Bachelors             13
# 9       37            Private  280464   Some-college             10
# 10      30          State-gov  141297      Bachelors             13
# ...    ...                ...     ...            ...            ...
# 32538   71                  ?  287372      Doctorate             16
# 32544   39          Local-gov  111499     Assoc-acdm             12
# 32553   53            Private  321865        Masters             14
# 32556   40            Private  154374        HS-grad              9
# 32559   52       Self-emp-inc  287927        HS-grad              9
#
#             marital_status          occupation    relationship  \
# 6       Married-civ-spouse     Exec-managerial         Husband
# ...

# %%
df_menor_ou_igual_que_50K = df.loc[df['yearly_wage'] == ' <=50K']
df_menor_ou_igual_que_50K
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 0       50   Self-emp-not-inc   83311      Bachelors             13
# 1       38            Private  215646        HS-grad              9
# 2       53            Private  234721           11th              7
# 3       28            Private  338409      Bachelors             13
# 4       37            Private  284582        Masters             14
# ...    ...                ...     ...            ...            ...
# 32552   32            Private  116138        Masters             14
# 32554   22            Private  310152   Some-college             10
# 32555   27            Private  257302     Assoc-acdm             12
# 32557   58            Private  151910        HS-grad              9
# 32558   22            Private  201490        HS-grad              9
#
#             marital_status          occupation    relationship  \
# 0       Married-civ-spouse     Exec-managerial         Husband
# ...

# %% [markdown]
# ## Verificando a Base

# %% [markdown]
# A base é bem construída, não há valores nulos, não sendo necessário um pré-processamento inicial

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# yearly_wage       0
# dtype: int64

# %% [markdown]
# A seguir é apresentada uma breve descrição com algumas estatísticas sobre os atributos numéricos da base

# %%
df.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# ## Funções Auxiliares

# %%
def grafico_atributo(df, atributo, anotacao="", hue_atributo = 'sem_hue', size = (8,5)):
    plt.figure(figsize=size)

    if hue_atributo == 'sem_hue':
        ax = sns.countplot(df[atributo]);
    else: 
        ax = sns.countplot(x = df[atributo], hue=df[hue_atributo]);
    
    ax.set_title(f'Atributo {atributo} {anotacao}', fontsize=15)
    plt.show();

def histograma_atributo(df, atributo, anotacao, bins = 10, size = (8,5)):
    plt.figure(figsize=size)
    
    ax = sns.histplot(data=df[atributo], bins=bins);
    ax.set_title(f'Histograma {atributo} {anotacao}', fontsize=15)
    plt.show()

def estatisticas_descritivas(df, atributo, anotacoes):
    print(anotacoes)
    print(f'Média: {df[atributo].mean()}')
    for i in range(len(df[atributo].mode())):
        print(f'Moda: {df[atributo].mode()[i]}')
    print(f'Percentil (25%): {df[atributo].quantile(q=0.25)}')
    print(f'Percentil (50% ou Mediana): {df[atributo].quantile(q=0.5)}') #print(df[atributo].median())
    print(f'Percentil (75%): {df[atributo].quantile(q=0.75)}')
    print(f'Valor Máximo: {df[atributo].max()}')
    print(f'Valor Mínimo: {df[atributo].min()}')
    print(f'Variância: {df[atributo].var()}')
    print(f'Desvio Padrão: {df[atributo].std()}')
    print("\n\n")

def boxplot_atributo(df, atributo, anotacao, size = (8,5)):
    plt.figure(figsize=size)
    
    ax = sns.boxplot(df[atributo]);
    ax.set_title(f'Boxplot {atributo} {anotacao}', fontsize=15)
    plt.show()

# %% [markdown]
# ## Exploração por atributo

# %% [markdown]
# ### yearly_wage
#
# > O atributo yearly_wage indica quanto o indivíduo ganha por ano.
#
# > No gráfico de barras a seguir, podemos observar que a base de treinamento é desbalanceada, tendo mais amostras de pessoas que ganham <=50K

# %%
atributo = 'yearly_wage'

grafico_atributo(df, atributo)

# %% [markdown]
# ### age
#
# > No histograma a seguir percebemos que a maioria das amostras estão com o atributo age entre um pouco menos que 20 até um pouco mais que 40, e vão diminuindo até chegar em 90.
#
# > Quando vemos o histograma para cada classe (<=50K e >50K), percebemos que a maioria dos >50K estão em torno de 40 anos.
#
# > Também percebe-se que a maioria daqueles em torno dos 20 anos estão na classe <=50K.
#
# > As medidas de tendência central tendem a ser menores para a classe <=50K

# %% [markdown]
# #### Histogramas

# %%
atributo = 'age'

histograma_atributo(df, atributo, '(todos os dados)', bins = 10)

histograma_atributo(df_menor_ou_igual_que_50K, atributo, '(<=50K)', bins = 10)

histograma_atributo(df_maior_que_50K, atributo, '(>50K)', bins = 10)

# %% [markdown]
# #### Estatisticas Descritivas

# %%
estatisticas_descritivas(df, atributo, 'Todos os Dados')

estatisticas_descritivas(df_maior_que_50K, atributo, '>50K')

estatisticas_descritivas(df_menor_ou_igual_que_50K, atributo, '<=50K')
# Out:
# Todos os Dados
# Média: 38.581633906633904
# Moda: 36
# Percentil (25%): 28.0
# Percentil (50% ou Mediana): 37.0
# Percentil (75%): 48.0
# Valor Máximo: 90
# Valor Mínimo: 17
# Variância: 186.06710946516068
# Desvio Padrão: 13.64064182746401
#
#
#
# >50K
# Média: 44.24984058155847
# Moda: 37
# Moda: 46
# Percentil (25%): 36.0
# Percentil (50% ou Mediana): 44.0
# Percentil (75%): 51.0
# Valor Máximo: 90
# Valor Mínimo: 19
# Variância: 110.6499441710111
# Desvio Padrão: 10.519027719851826
#
#
#
# <=50K
# Média: 36.78364820583357
# Moda: 23
# Percentil (25%): 25.0
# Percentil (50% ou Mediana): 34.0
# Percentil (75%): 46.0
# Valor Máximo: 90
# Valor Mínimo: 17
# Variância: 196.57063478456178
# Desvio Padrão: 14.020365001830793

# %% [markdown]
# #### Boxplot

# %%
boxplot_atributo(df, atributo, '(todos os Dados)')

boxplot_atributo(df_maior_que_50K, atributo, '(>50K)')

boxplot_atributo(df_menor_ou_igual_que_50K, atributo, '(<=50K)')

# %% [markdown]
# ### workclass
#
# > Percebe-se maior concentração de amostras com workclass Private

# %%
atributo = 'workclass'

grafico_atributo(df, atributo, size=(20,5))

grafico_atributo(df, atributo, anotacao="(por classe)", hue_atributo = 'yearly_wage', size = (20,5))

# %% [markdown]
# ### fnlwgt
#
# > Para esse atributo, a distribuição é bem parecida para as 2 classes
#
# > No Boxplot, as amostras acima são potenciais outliers

# %% [markdown]
# #### Histogramas

# %%
atributo = 'fnlwgt'

histograma_atributo(df, atributo, '(todos os dados)', bins = 10)

histograma_atributo(df_menor_ou_igual_que_50K, atributo, '(<=50K)', bins = 10)

histograma_atributo(df_maior_que_50K, atributo, '(>50K)', bins = 10)

# %% [markdown]
# #### Estatisticas Descritivas
#
# >

# %%
estatisticas_descritivas(df, atributo, 'Todos os Dados')

estatisticas_descritivas(df_maior_que_50K, atributo, '>50K')

estatisticas_descritivas(df_menor_ou_igual_que_50K, atributo, '<=50K')
# Out:
# Todos os Dados
# Média: 189781.81437346438
# Moda: 123011
# Moda: 164190
# Moda: 203488
# Percentil (25%): 117831.5
# Percentil (50% ou Mediana): 178363.0
# Percentil (75%): 237054.5
# Valor Máximo: 1484705
# Valor Mínimo: 12285
# Variância: 11140752875.591145
# Desvio Padrão: 105549.76492437652
#
#
#
# >50K
# Média: 188005.0
# Moda: 123011
# Percentil (25%): 119101.0
# Percentil (50% ou Mediana): 176101.0
# Percentil (75%): 230959.0
# Valor Máximo: 1226583
# Valor Mínimo: 14878
# Variância: 10514815717.01301
# Desvio Padrão: 102541.77547230694
#
#
#
# <=50K
# Média: 190345.42946721145
# Moda: 113364
# Moda: 123983
# Moda: 216129
# Percentil (25%): 117606.0
# Percentil (50% ou Mediana): 179468.0
# Percentil (75%): 239028.0
# Valor Máximo: 1484705
# Valor Mínimo: 12285
# Variância: 11338417784.13046
# Desvio Padrão: 106482.00685623116

# %% [markdown]
# #### Boxplot

# %%
boxplot_atributo(df, atributo, '(todos os Dados)')

boxplot_atributo(df_maior_que_50K, atributo, '(>50K)')

boxplot_atributo(df_menor_ou_igual_que_50K, atributo, '(<=50K)')

# %% [markdown]
# ###education
#
# > Para o education, existem mais amostras das classes HS-grad, Some-college e Bachelors, respectivamente
#
# > Mas para >50k, a categoria com mais amostras é a Bachelors

# %%
atributo = 'education'

grafico_atributo(df, atributo, size=(25,5))

grafico_atributo(df, atributo, anotacao="(por classe)", hue_atributo = 'yearly_wage', size = (25,5))

# %% [markdown]
# ###education_num
#
# > A maioria dos dados estão em torno de 10, para todas as classes
#
# > As médias da classe >50K são mais elevadas que da classe <=50K
#
# > No Boxplot, percebe-se alguns outliers, valores baixos de education_num na classe no >50K

# %% [markdown]
# #### Histogramas

# %%
atributo = 'education_num'

histograma_atributo(df, atributo, '(todos os dados)', bins = 10)

histograma_atributo(df_menor_ou_igual_que_50K, atributo, '(<=50K)', bins = 10)

histograma_atributo(df_maior_que_50K, atributo, '(>50K)', bins = 10)

# %% [markdown]
# #### Estatisticas Descritivas
#
# >

# %%
estatisticas_descritivas(df, atributo, 'Todos os Dados')

estatisticas_descritivas(df_maior_que_50K, atributo, '>50K')

estatisticas_descritivas(df_menor_ou_igual_que_50K, atributo, '<=50K')
# Out:
# Todos os Dados
# Média: 10.08058968058968
# Moda: 9
# Percentil (25%): 9.0
# Percentil (50% ou Mediana): 10.0
# Percentil (75%): 12.0
# Valor Máximo: 16
# Valor Mínimo: 1
# Variância: 6.618831434569017
# Desvio Padrão: 2.572708968105218
#
#
#
# >50K
# Média: 11.611656676444332
# Moda: 13
# Percentil (25%): 10.0
# Percentil (50% ou Mediana): 12.0
# Percentil (75%): 13.0
# Valor Máximo: 16
# Valor Mínimo: 2
# Variância: 5.6888385943588
# Desvio Padrão: 2.385128632665081
#
#
#
# <=50K
# Média: 9.594926979246733
# Moda: 9
# Percentil (25%): 9.0
# Percentil (50% ou Mediana): 9.0
# Percentil (75%): 10.0
# Valor Máximo: 16
# Valor Mínimo: 1
# Variância: 5.934582241411018
# Desvio Padrão: 2.4360998012008905

# %% [markdown]
# #### Boxplot

# %%
boxplot_atributo(df, atributo, '(todos os Dados)')

boxplot_atributo(df_maior_que_50K, atributo, '(>50K)')

boxplot_atributo(df_menor_ou_igual_que_50K, atributo, '(<=50K)')

# %% [markdown]
# ###marital_status
#
# > A maioria dos dados são das categorias Married-civ-spouse e Never-married
#
# > A grande maioria das amostras da classe >50K são da categoria Married-civ-spouse

# %%
atributo = 'marital_status'

grafico_atributo(df, atributo, size=(15,5))

grafico_atributo(df, atributo, anotacao="(por classe)", hue_atributo = 'yearly_wage', size = (15,5))

# %% [markdown]
# ###occupation
#
# > Há várias categorias com valores parecidos nesse atributo, mas para a classe >50K, a maioria são das classes Exec-managerial e Prof-speacialty

# %%
atributo = 'occupation'

grafico_atributo(df, atributo, size=(25,5))

grafico_atributo(df, atributo, anotacao="(por classe)", hue_atributo = 'yearly_wage', size = (25,5))

# %% [markdown]
# ###relationship
#
# > As 2 maiores categorias são Husband e Not-in-family
#
# > A maioria das amostras Not-in-family são da classe <=50K

# %%
atributo = 'relationship'

grafico_atributo(df, atributo, size=(15,5))

grafico_atributo(df, atributo, anotacao="(por classe)", hue_atributo = 'yearly_wage', size = (15,5))

# %% [markdown]
# ###race
#
# > A maioria dos dados são da categoria White

# %%
atributo = 'race'

grafico_atributo(df, atributo, size=(15,5))

grafico_atributo(df, atributo, anotacao="(por classe)", hue_atributo = 'yearly_wage', size = (15,5))

# %% [markdown]
# ###sex
#
# > A maioria das amostras são da categoria Male
#
# > Um pouco menos de 1/3 do Male são da categoria >50K
#
# > Um pouco menos de 1/5 do Female são da categoria <=50K

# %%
atributo = 'sex'

grafico_atributo(df, atributo, size=(10,5))

grafico_atributo(df, atributo, anotacao="(por classe)", hue_atributo = 'yearly_wage', size = (10,5))

# %% [markdown]
# ###capital_gain
#
# > Os dados estão concentrados nos valores abaixo de 20000
#
# > O desvio padrão desse atributo é muito elevado, pois existem valores muito baixos e valores muito altos

# %% [markdown]
# #### Histogramas

# %%
atributo = 'capital_gain'

histograma_atributo(df, atributo, '(todos os dados)', bins = 10)

histograma_atributo(df_menor_ou_igual_que_50K, atributo, '(<=50K)', bins = 10)

histograma_atributo(df_maior_que_50K, atributo, '(>50K)', bins = 10)

# %% [markdown]
# #### Estatisticas Descritivas
#
# >

# %%
estatisticas_descritivas(df, atributo, 'Todos os Dados')

estatisticas_descritivas(df_maior_que_50K, atributo, '>50K')

estatisticas_descritivas(df_menor_ou_igual_que_50K, atributo, '<=50K')
# Out:
# Todos os Dados
# Média: 1077.615171990172
# Moda: 0
# Percentil (25%): 0.0
# Percentil (50% ou Mediana): 0.0
# Percentil (75%): 0.0
# Valor Máximo: 99999
# Valor Mínimo: 0
# Variância: 54544177.45096919
# Desvio Padrão: 7385.402998548501
#
#
#
# >50K
# Média: 4006.142456319347
# Moda: 0
# Percentil (25%): 0.0
# Percentil (50% ou Mediana): 0.0
# Percentil (75%): 0.0
# Valor Máximo: 99999
# Valor Mínimo: 0
# Variância: 212295942.7839129
# Desvio Padrão: 14570.37895128033
#
#
#
# <=50K
# Média: 148.6705368340143
# Moda: 0
# Percentil (25%): 0.0
# Percentil (50% ou Mediana): 0.0
# Percentil (75%): 0.0
# Valor Máximo: 41310
# Valor Mínimo: 0
# Variância: 927508.9106259398
# Desvio Padrão: 963.072640368285

# %% [markdown]
# #### Boxplot

# %%
boxplot_atributo(df, atributo, '(todos os Dados)')

boxplot_atributo(df_maior_que_50K, atributo, '(>50K)')

boxplot_atributo(df_menor_ou_igual_que_50K, atributo, '(<=50K)')

# %% [markdown]
# ###capital_loss
#
# > A maioria dos dados estão abaixo de 500
#
# > Mas existem alguns dados em torno dos 2000
#
# > Também apresenta desvio padrão bem elevado

# %% [markdown]
# #### Histogramas

# %%
atributo = 'capital_loss'

histograma_atributo(df, atributo, '(todos os dados)', bins = 10)

histograma_atributo(df_menor_ou_igual_que_50K, atributo, '(<=50K)', bins = 10)

histograma_atributo(df_maior_que_50K, atributo, '(>50K)', bins = 10)

# %% [markdown]
# #### Estatisticas Descritivas
#
# >

# %%
estatisticas_descritivas(df, atributo, 'Todos os Dados')

estatisticas_descritivas(df_maior_que_50K, atributo, '>50K')

estatisticas_descritivas(df_menor_ou_igual_que_50K, atributo, '<=50K')
# Out:
# Todos os Dados
# Média: 87.30651105651106
# Moda: 0
# Percentil (25%): 0.0
# Percentil (50% ou Mediana): 0.0
# Percentil (75%): 0.0
# Valor Máximo: 4356
# Valor Mínimo: 0
# Variância: 162381.69086948785
# Desvio Padrão: 402.96611627962943
#
#
#
# >50K
# Média: 195.00153041703865
# Moda: 0
# Percentil (25%): 0.0
# Percentil (50% ou Mediana): 0.0
# Percentil (75%): 0.0
# Valor Máximo: 3683
# Valor Mínimo: 0
# Variância: 354605.4507629637
# Desvio Padrão: 595.4875739786379
#
#
#
# <=50K
# Média: 53.14507059347061
# Moda: 0
# Percentil (25%): 0.0
# Percentil (50% ou Mediana): 0.0
# Percentil (75%): 0.0
# Valor Máximo: 4356
# Valor Mínimo: 0
# Variância: 96572.94060105395
# Desvio Padrão: 310.7618712150092

# %% [markdown]
# #### Boxplot

# %%
boxplot_atributo(df, atributo, '(todos os Dados)')

boxplot_atributo(df_maior_que_50K, atributo, '(>50K)')

boxplot_atributo(df_menor_ou_igual_que_50K, atributo, '(<=50K)')

# %% [markdown]
# ###hours_per_week
#
# > A maioria dos dados ficam abaixo de 40
#
# > Mas para a classe >50K, existe um pico elevado, quando proporcialmente comparado, nos valores abaixo de 60, o que é refletido na média mais elevada

# %% [markdown]
# #### Histogramas

# %%
atributo = 'hours_per_week'

histograma_atributo(df, atributo, '(todos os dados)', bins = 10)

histograma_atributo(df_menor_ou_igual_que_50K, atributo, '(<=50K)', bins = 10)

histograma_atributo(df_maior_que_50K, atributo, '(>50K)', bins = 10)

# %% [markdown]
# #### Estatisticas Descritivas
#
# >

# %%
estatisticas_descritivas(df, atributo, 'Todos os Dados')

estatisticas_descritivas(df_maior_que_50K, atributo, '>50K')

estatisticas_descritivas(df_menor_ou_igual_que_50K, atributo, '<=50K')
# Out:
# Todos os Dados
# Média: 40.437469287469284
# Moda: 40
# Percentil (25%): 40.0
# Percentil (50% ou Mediana): 40.0
# Percentil (75%): 45.0
# Valor Máximo: 99
# Valor Mínimo: 1
# Variância: 152.46367171808984
# Desvio Padrão: 12.347618058479531
#
#
#
# >50K
# Média: 45.473026399693914
# Moda: 40
# Percentil (25%): 40.0
# Percentil (50% ou Mediana): 40.0
# Percentil (75%): 50.0
# Valor Máximo: 99
# Valor Mínimo: 1
# Variância: 121.28552870963459
# Desvio Padrão: 11.012970930209278
#
#
#
# <=50K
# Média: 38.840163437032245
# Moda: 40
# Percentil (25%): 35.0
# Percentil (50% ou Mediana): 40.0
# Percentil (75%): 40.0
# Valor Máximo: 99
# Valor Mínimo: 1
# Variância: 151.76371412491767
# Desvio Padrão: 12.319241621338453

# %% [markdown]
# #### Boxplot

# %%
boxplot_atributo(df, atributo, '(todos os Dados)')

boxplot_atributo(df_maior_que_50K, atributo, '(>50K)')

boxplot_atributo(df_menor_ou_igual_que_50K, atributo, '(<=50K)')

# %% [markdown]
# ###native_country
#
# > A maioria das amostras são da categoria United-States

# %%
# como são muitas categorias, é necessário utilizar a ferramenta de lupa nos gráficos a seguir

atributo = 'native_country'

grafico_atributo(df, atributo, size=(100,20))

grafico_atributo(df, atributo, anotacao="(por classe)", hue_atributo = 'yearly_wage', size = (100,20))

# %% [markdown]
# ## Correlação
#
# > Há pouca correlação entre os atributos numéricos da base, indicando que um não depende do outro

# %%
corr = df.corr()

plt.figure(figsize=(15,15))
ax = sns.heatmap(corr, cmap="Blues", annot=True)
ax.set_title(f'Correlação', fontsize=15)
plt.show();

# %% [markdown]
# # Fases de Treinamento e Validação dos Modelos
#
# > O problema apresentado é do tipo Classificação, busca-se separar os dados de teste nas classes >50K e <=50K.
#
# > Para solucionar o problema da previsão dos salários, eu utilizei todos os atributos da base, tirando o rótulo, e realizei uma etapa de pré-processamento, que transformou os dados da base. Inicialmente eu dividi a base "wage_train" em duas, base de treino (80%) e base de validação (20%), pois assim consegueria medir a performace dos modelos.
#
# > Nesses dados eu realizei 3 transformações, o primeiro foi o LabelEnconder, que basicamente converte os atributos categoricos (workclass, education, marital_status, occupation, relationship, race, sex e native_country) em números, pois os modelos não trabalham com strings nesses categorias.
#
# > O segundo foi o OneHotEnconder, que basicamente pega esses atributos que eram categoricos, e converte em um array onde fica 1 na coluna que representa aquela categoria, e 0 nas outras colunas, esse pré-processamento serve para os modelos não "darem pesos" diferentes para categorias com números diferentes, se for 0 para categoria_X e 1 para categoria_Y, o modelo poderia achar que o categoria_Y é mais importante por ser maior, ou vice-versa.
#
# > O terceiro foi o Escalonamento dos dados, todos os valores na mesma escala, o que pode melhorar os resultados de alguns modelos.
#
# > Para este problema eu utilizei os algoritmos de aprendizagem de máquina: Árvore de Descisão, KNN, Naive Bayes, Random Forest, Regressão Logística e SVM. Apliquei os mesmos dados de treinamento para cada modelo, e analisei os resultados na fase de validação.
#
# > Para medir a performance dos modelos, utilizei as métricas: Acurácia, Precisão e Recall, além de utilizar a Matriz de Confusão para análise dos resultados. Utilizar todas essas métricas em conjunto, faz a análise ser menos influenciada pelo desbalanceamento das classes da base.
#
# > Para os experimentos que eu realizei, o melhor resultado na fase de validação foi com o modelo Random Forest, este trouxe os maiores valores para as 3 métricas de performance. Acurácia: 0,85; Precisão: 0,80; Recall: 0,77. Por isso, esse foi o modelo escolhido.
#
# > Uma das características do Random Forest, é que ele é um conjunto de árvores de descisão, por um lado, isso é um pró pois trás o melhor resultado em conjunto do que se utilizasse apenas uma árvore, mas por outro lado, isso não um contra, pois utiliza mais processamento do que uma simples árvore de descisão, apesar disso, ainda utiliza menos processamento do que outros modelos, como o SVM.

# %% [markdown]
# ## Bibliotecas

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression


from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

import numpy as np

# %% [markdown]
# ## Funções Auxiliares

# %%
def avaliacao(rotulos_validacao, rotulos_previstos, modelo):

    print(f'Acurácia: {accuracy_score(rotulos_validacao, rotulos_previstos)}')
    print(f"Precisão: {precision_score(rotulos_validacao, rotulos_previstos, average='macro')}")
    print(f"Recall: {recall_score(rotulos_validacao, rotulos_previstos, average='macro')}")
    print(f'Matriz de Confusão: ')
    cm = confusion_matrix(rotulos_validacao, rotulos_previstos, labels=modelo.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=modelo.classes_)
    disp.plot()

# %% [markdown]
# ## Tranformações dos dados

# %%
df_atributos = df.iloc[:, 0:14].values
df_rotulos = df.iloc[:, 14].values

# %% [markdown]
# ### Divisão em treino e validação

# %%
atributos_treino, atributos_validacao, rotulos_treino, rotulos_validacao = train_test_split(df_atributos, df_rotulos, test_size = 0.20, random_state=0)

# %% [markdown]
# ### LabelEncoder

# %%
label_enconder_workclass = LabelEncoder()
label_enconder_education = LabelEncoder()
label_enconder_marital_status = LabelEncoder()
label_enconder_occupation = LabelEncoder()
label_enconder_relationship = LabelEncoder()
label_enconder_race = LabelEncoder()
label_enconder_sex = LabelEncoder()
label_enconder_native_country = LabelEncoder()

# %%
# Treino
atributos_treino[:, 1] = label_enconder_workclass.fit_transform(atributos_treino[:, 1])
atributos_treino[:, 3] = label_enconder_education.fit_transform(atributos_treino[:, 3])
atributos_treino[:, 5] = label_enconder_marital_status.fit_transform(atributos_treino[:, 5])
atributos_treino[:, 6] = label_enconder_occupation.fit_transform(atributos_treino[:, 6])
atributos_treino[:, 7] = label_enconder_relationship.fit_transform(atributos_treino[:, 7])
atributos_treino[:, 8] = label_enconder_race.fit_transform(atributos_treino[:, 8])
atributos_treino[:, 9] = label_enconder_sex.fit_transform(atributos_treino[:, 9])
atributos_treino[:, 13] = label_enconder_native_country.fit_transform(atributos_treino[:, 13])

# %%
# Validacao
atributos_validacao[:, 1] = label_enconder_workclass.transform(atributos_validacao[:, 1])
atributos_validacao[:, 3] = label_enconder_education.transform(atributos_validacao[:, 3])
atributos_validacao[:, 5] = label_enconder_marital_status.transform(atributos_validacao[:, 5])
atributos_validacao[:, 6] = label_enconder_occupation.transform(atributos_validacao[:, 6])
atributos_validacao[:, 7] = label_enconder_relationship.transform(atributos_validacao[:, 7])
atributos_validacao[:, 8] = label_enconder_race.transform(atributos_validacao[:, 8])
atributos_validacao[:, 9] = label_enconder_sex.transform(atributos_validacao[:, 9])
atributos_validacao[:, 13] = label_enconder_native_country.transform(atributos_validacao[:, 13])

# %% [markdown]
# ### One Hot Encoder

# %%
onehotenconder = ColumnTransformer(transformers = [('OneHot', OneHotEncoder(), [1, 3, 5, 6, 7, 8, 9, 13])], remainder='passthrough')

# %%
#Treino
atributos_treino = onehotenconder.fit_transform(atributos_treino).toarray()

# %%
#Validacao
atributos_validacao = onehotenconder.transform(atributos_validacao).toarray()

# %% [markdown]
# ### Escalonamento

# %%
standardscaler = StandardScaler()

# %%
#Treino
atributos_treino = standardscaler.fit_transform(atributos_treino)

# %%
#Validacao
atributos_validacao = standardscaler.transform(atributos_validacao)

# %% [markdown]
# ## Modelos

# %% [markdown]
# ### Árvore de Descisão
#
# > Acurácia: 0.816031941031941
#
# > Precisão: 0.7469644263650446
#
# > Recall: 0.7456518340688116

# %% [markdown]
# ####Treino

# %%
modelo_ad = DecisionTreeClassifier(random_state=0)
modelo_ad.fit(atributos_treino, rotulos_treino)
# Out:
# DecisionTreeClassifier(random_state=0)

# %% [markdown]
# ####Validação

# %%
rotulos_previstos = modelo_ad.predict(atributos_validacao)

avaliacao(rotulos_validacao, rotulos_previstos, modelo_ad)
# Out:
# Acurácia: 0.816031941031941
# Precisão: 0.7469644263650446
# Recall: 0.7456518340688116
# Matriz de Confusão:

# %% [markdown]
# ### KNN
#
# > Acurácia: 0.8149570024570024
#
# > Precisão: 0.7458302446256486
#
# > Recall: 0.7306018252145299

# %% [markdown]
# ####Treino

# %%
modelo_knn = KNeighborsClassifier(n_neighbors=3)
modelo_knn.fit(atributos_treino, rotulos_treino)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ####Validação

# %%
rotulos_previstos = modelo_knn.predict(atributos_validacao)

avaliacao(rotulos_validacao, rotulos_previstos, modelo_knn)
# Out:
# Acurácia: 0.8149570024570024
# Precisão: 0.7458302446256486
# Recall: 0.7306018252145299
# Matriz de Confusão:

# %% [markdown]
# ### Naive Bayes
#
# > Acurácia: 0.44364250614250617
#
# > Precisão: 0.6318518359350034
#
# > Recall: 0.6241854222843788

# %% [markdown]
# #### Treino

# %%
modelo_nb = GaussianNB()
modelo_nb.fit(atributos_treino, rotulos_treino)
# Out:
# GaussianNB()

# %% [markdown]
# ####Validação

# %%
rotulos_previstos = modelo_nb.predict(atributos_validacao)

avaliacao(rotulos_validacao, rotulos_previstos, modelo_nb)
# Out:
# Acurácia: 0.44364250614250617
# Precisão: 0.6318518359350034
# Recall: 0.6241854222843788
# Matriz de Confusão:

# %% [markdown]
# ### Random Forest
#
# > Acurácia: 0.855036855036855
#
# > Precisão: 0.8092037597005
#
# > Recall: 0.7741409562754156

# %% [markdown]
# ####Treino

# %%
modelo_rf = RandomForestClassifier(n_estimators=50, random_state=0)
modelo_rf.fit(atributos_treino, rotulos_treino)
# Out:
# RandomForestClassifier(n_estimators=50, random_state=0)

# %% [markdown]
# ####Validação

# %%
rotulos_previstos = modelo_rf.predict(atributos_validacao)

avaliacao(rotulos_validacao, rotulos_previstos, modelo_rf)
# Out:
# Acurácia: 0.855036855036855
# Precisão: 0.8092037597005
# Recall: 0.7741409562754156
# Matriz de Confusão:

# %% [markdown]
# ### Regressão Logística
#
# > Acurácia: 0.8511977886977887
#
# > Precisão: 0.8064419798068774
#
# > Recall: 0.7621302039987623

# %% [markdown]
# ####Treino

# %%
modelo_rl = LogisticRegression(random_state=0)
modelo_rl.fit(atributos_treino, rotulos_treino)
# Out:
# LogisticRegression(random_state=0)

# %% [markdown]
# ####Validação

# %%
rotulos_previstos = modelo_rl.predict(atributos_validacao)

avaliacao(rotulos_validacao, rotulos_previstos, modelo_rl)
# Out:
# Acurácia: 0.8511977886977887
# Precisão: 0.8064419798068774
# Recall: 0.7621302039987623
# Matriz de Confusão:

# %% [markdown]
# ### SVM
#
# > Acurácia: 0.8493550368550369
#
# > Precisão: 0.806323483724736
#
# > Recall: 0.7542995160307908

# %% [markdown]
# ####Treino

# %%
modelo_svm = SVC(kernel='linear', random_state=0)
modelo_svm.fit(atributos_treino, rotulos_treino)
# Out:
# SVC(kernel='linear', random_state=0)

# %% [markdown]
# ####Validação

# %%
rotulos_previstos = modelo_svm.predict(atributos_validacao)

avaliacao(rotulos_validacao, rotulos_previstos, modelo_svm)
# Out:
# Acurácia: 0.8493550368550369
# Precisão: 0.806323483724736
# Recall: 0.7542995160307908
# Matriz de Confusão:

# %% [markdown]
# ## Modelo Escolhido: Random Forest, pois tem as maiores métricas.

# %% [markdown]
# # Fase de Teste

# %% [markdown]
# ## Carregando a base de teste

# %%
df_teste = pd.read_csv('wage_test.csv')
df_teste = df_teste.drop(columns=['Unnamed: 0'])
df_teste
# Out:
#        age      workclass  fnlwgt      education  education_num  \
# 0       38        Private   89814        HS-grad              9
# 1       28      Local-gov  336951     Assoc-acdm             12
# 2       44        Private  160323   Some-college             10
# 3       18              ?  103497   Some-college             10
# 4       34        Private  198693           10th              6
# ...    ...            ...     ...            ...            ...
# 16275   39        Private  215419      Bachelors             13
# 16276   64              ?  321403        HS-grad              9
# 16277   38        Private  374983      Bachelors             13
# 16278   44        Private   83891      Bachelors             13
# 16279   35   Self-emp-inc  182148      Bachelors             13
#
#             marital_status          occupation     relationship  \
# 0       Married-civ-spouse     Farming-fishing          Husband
# 1       Married-civ-spouse     Protective-serv          Husband
# ...

# %% [markdown]
# ## Tratamento da Base

# %%
df_teste = df_teste.iloc[:, 0:14].values

# %%
#LabelEncoder
df_teste[:, 1] = label_enconder_workclass.transform(df_teste[:, 1])
df_teste[:, 3] = label_enconder_education.transform(df_teste[:, 3])
df_teste[:, 5] = label_enconder_marital_status.transform(df_teste[:, 5])
df_teste[:, 6] = label_enconder_occupation.transform(df_teste[:, 6])
df_teste[:, 7] = label_enconder_relationship.transform(df_teste[:, 7])
df_teste[:, 8] = label_enconder_race.transform(df_teste[:, 8])
df_teste[:, 9] = label_enconder_sex.transform(df_teste[:, 9])
df_teste[:, 13] = label_enconder_native_country.transform(df_teste[:, 13])

# %%
#OneHotEncoder
df_teste = onehotenconder.transform(df_teste).toarray()

# %%
#Escalonamento
df_teste = standardscaler.transform(df_teste)

# %% [markdown]
# ## Teste

# %%
rotulos_previstos_teste = modelo_rf.predict(df_teste)

# %% [markdown]
# ## Salvando resultados

# %%
index = np.array(range(0, len(rotulos_previstos_teste)))
pred = np.transpose(np.array([index, rotulos_previstos_teste]))

# %%
predicted_csv = pd.DataFrame(pred, columns = ['rowNumber','predictedValues'])
predicted_csv
# Out:
#       rowNumber predictedValues
# 0             0           <=50K
# 1             1            >50K
# 2             2            >50K
# 3             3           <=50K
# 4             4           <=50K
# ...         ...             ...
# 16275     16275           <=50K
# 16276     16276           <=50K
# 16277     16277            >50K
# 16278     16278           <=50K
# 16279     16279            >50K
#
# [16280 rows x 2 columns]

# %%
predicted_csv.to_csv("predicted.csv", index=False)
